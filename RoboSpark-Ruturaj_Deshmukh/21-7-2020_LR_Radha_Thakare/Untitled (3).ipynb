# %%
import pandas as pd
import pandas

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("50_Startups.csv")

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.isnull().values.any()
# Out:
# False

# %%
pd.set_option('display.float_format', lambda x : '%.2f' %x)

# %%
df[["R&D Spend","Administration","Marketing Spend","State","Profit"]].describe()
# Out:
#        R&D Spend  Administration  Marketing Spend    Profit
# count      50.00           50.00            50.00     50.00
# mean    73721.62       121344.64        211025.10 112012.64
# std     45902.26        28017.80        122290.31  40306.18
# min         0.00        51283.14             0.00  14681.40
# 25%     39936.37       103730.88        129300.13  90138.90
# 50%     73051.08       122699.79        212716.24 107978.19
# 75%    101602.80       144842.18        299469.08 139765.98
# max    165349.20       182645.56        471784.10 192261.83

# %%
pd.set_option('display.max_columns',5)

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 0   165349.20       136897.80        471784.10    New York 192261.83
# 1   162597.70       151377.59        443898.53  California 191792.06
# 2   153441.51       101145.55        407934.54     Florida 191050.39
# 3   144372.41       118671.85        383199.62    New York 182901.99
# 4   142107.34        91391.77        366168.42     Florida 166187.94
# 5   131876.90        99814.71        362861.36    New York 156991.12
# 6   134615.46       147198.87        127716.82  California 156122.51
# 7   130298.13       145530.06        323876.68     Florida 155752.60
# 8   120542.52       148718.95        311613.29    New York 152211.77
# 9   123334.88       108679.17        304981.62  California 149759.96
# 10  101913.08       110594.11        229160.95     Florida 146121.95
# 11  100671.96        91790.61        249744.55  California 144259.40
# 12   93863.75       127320.38        249839.44     Florida 141585.52
# ...

# %%
plt.scatter(df["Marketing Spend"], df["Profit"])
plt.axis([0, 500000, 0, 5000000])
# Out:
# [0, 500000, 0, 5000000]

# %%
df2 = df[["Marketing Spend","Profit"]]

# %%
df2.head()
# Out:
#    Marketing Spend    Profit
# 0        471784.10 192261.83
# 1        443898.53 191792.06
# 2        407934.54 191050.39
# 3        383199.62 182901.99
# 4        366168.42 166187.94

# %%
sns.jointplot('Marketing Spend','Profit',data = df2,xlim=(50,50),ylim =(50,50),height=10,alpha=0.7,marker='+')
# Out:
# E:\anaconda\lib\site-packages\seaborn\axisgrid.py:1735: UserWarning: Attempting to set identical bottom == top == 50 results in singular transformations; automatically expanding.
#   ax_joint.set_ylim(ylim)

# %%
df_192261.83_N.to_csv("df_192261.83_N.csv", index = False)
# Out:
#   File "<ipython-input-20-7b5b0f67240c>", line 1
#     df_192261.83_N.to_csv("df_192261.83_N.csv", index = False)
#                 ^
# SyntaxError: invalid token
